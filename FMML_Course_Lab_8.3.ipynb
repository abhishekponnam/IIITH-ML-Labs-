# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekponnam/IIITH-ML-Labs-/blob/main/FMML_Course_Lab_8.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-08 12:57:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   231MB/s    in 0.3s
#
# 2022-06-08 12:57:53 (231 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31934   1301.3485v2  Large-scale relational learning becomes crucia...    cs
# 7572   1802.03713v1  It has been widely observed that many activati...  stat
# 38947   1403.6318v1  Recent years have seen growing interest in exp...    cs
# 7189   1710.11469v3  When training a deep network for image classif...  stat
# 198    1707.01357v1  Content-invariance in mapping codes learned by...    cs
# ...             ...                                                ...   ...
# 12361  1712.07042v2  Structure based ligand discovery is one of the...  stat
# 21639   1209.3230v1  In the paper, we consider the problem of link ...  stat
# 12983   1102.5288v2  Recovery of low-rank matrices has recently see...  stat
# 31947   1304.1391v1  Applications of non-linear kernel Support Vect...    cs
# 7688   1802.08626v1  We address the problem of algorithmic fairness...  stat
#
#                                                    title  year  \
# 31934  A Semantic Matching Energy Function for Learni...  2013
# 7572   Optimizing Neural Networks in the Equivalent C...  2018
# 38947  Stabilizing dual-energy X-ray computed tomogra...  2014
# 7189   Conditional Variance Penalties and Domain Shif...  2017
# 198    Improving Content-Invariance in Gated Autoenco...  2017
# ...                                                  ...   ...
# 12361  Development and evaluation of a deep learning ...  2017
# 21639  Link Prediction in Graphs with Autoregressive ...  2012
# 12983  Sparse Bayesian Methods for Low-Rank Matrix Es...  2011
# 31947  Fast SVM training using approximate extreme po...  2013
# 7688   Empirical Risk Minimization under Fairness Con...  2018
#
#                                                 keywords
# 31934  [relational, structured, generated, applicatio...
# 7572   [activation, functions, rescaling, invariant, ...
# 38947  [exploiting, measurements, tomography, charact...
# 7189   [classification, distinguish, classification, ...
# 198    [invariance, invariance, substantially, extend...
# ...                                                  ...
# 12361  [structure, discovery, successful, approaches,...
# 21639  [prediction, autoregressive, information, pred...
# 12983  [significant, engineering, motivated, theoreti...
# 31947  [applications, seriously, excessive, modificat...
# 7688   [algorithmic, sensitive, variables, influence,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31934    [relational, structured, generated, applicatio...
# 7572     [activation, functions, rescaling, invariant, ...
# 38947    [exploiting, measurements, tomography, charact...
# 7189     [classification, distinguish, classification, ...
# 198      [invariance, invariance, substantially, extend...
#                                ...
# 21991    [important, classifier, quantifies, predictive...
# 21644    [geometrically, motivated, algorithm, nonnegat...
# 12509    [recognition, classification, applications, ma...
# 25204    [histopathological, extraction, classification...
# 19573    [constrained, applications, especially, commun...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8902 words.
# Out of those 4617 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6468de73-46e5-4aa4-a382-4a5955aecba4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6468de73-46e5-4aa4-a382-4a5955aecba4")) {                    Plotly.newPlot(                        "6468de73-46e5-4aa4-a382-4a5955aecba4",                        [{"x":["empirically","application","computational","components","semantics","architecture","probabilities","literature","performance","prediction","competitive","plausible","structured","retrieval","relational","processing","information","generated","continuous","optimization","conducted","propagation","represent","optimizing","significantly","different","operation","characterize","equivalent","invariant","complexity","redundant","particular","efficient","including","algorithms","experimental","gradients","rescaling","functions","properties","demonstrate","convolutional","stochastic","effectiveness","activation","connected","dimension","conventional","simulations","computationally","magnitude","inversion","stabilize","estimates","regularization","motivated","resulting","stabilizing","complicated","tomography","direction","alternating","exploiting","multipliers","measurements","attractive","performed","techniques","physically","sensitive","artifacts","coefficients","characterization","distribution","decomposing","materials","commercial","absorption","reconstructions","iterative","classification","substantially","consistency","condition","conditional","typically","orthogonal","influence","applications","partially","penalties","variables","brightness","distinguish","specifically","identifier","sometimes","robustness","following","adversarial","minimizing","generally","regression","interventions","exhibiting","improving","unsupervised","reconstruction","penalizes","experiments","knowledge","symmetric","invariance","autoencoders","exhibited","transformations","extending","bootstrapping","effectively","principally","recursive","framework","assumption","practical","convexity","convergence","efficiency","algorithm","numerical","comparing","minimization","respective","sufficient","reasonable","precisely","stakeholders","discomfort","foundation","questions","desiderata","consideration","significant","injecting","interpretable","synthesis","supervisory","evaluation","objective","estimation","sequences","supervised","simultaneously","performing","comparably","independently","empirical","comparable","unstructured","established","demonstrates","monocular","favorably","explosive","automated","microwave","restricted","detecting","something","environmental","statistical","processed","controlling","validated","implemented","detection","implement","statistically","environment","approximated","benchmark","reconstruct","curvature","refinement","interpolate","variational","superiority","interpolation","estimated","resolution","subjective","testified","curvatures","optimized","technique","measurement","dimensions","generalize","approaches","metrology"],"y":[86,258,304,96,91,247,58,115,884,218,118,30,116,94,38,293,667,152,126,286,67,70,110,42,257,729,57,50,60,63,225,17,263,375,258,583,383,26,1,205,204,567,400,118,214,38,60,58,95,34,94,65,6,7,80,66,60,152,3,30,27,66,21,72,10,49,23,129,374,11,63,23,38,28,220,11,13,19,2,9,71,514,33,58,58,107,90,18,53,443,55,4,107,4,25,170,4,20,83,66,94,57,71,112,9,9,113,134,88,4,625,401,18,16,16,3,44,37,10,113,3,24,557,61,148,5,108,167,794,75,94,58,11,77,40,26,4,1,20,79,1,31,232,2,29,39,7,278,160,196,121,163,115,65,8,36,137,81,34,57,46,29,28,5,107,4,53,70,6,15,168,26,17,41,109,353,72,21,130,13,192,37,8,16,6,40,40,21,59,126,30,1,4,44,224,31,35,40,433,1],"type":"bar"},{"x":["empirically","application","computational","components","semantics","architecture","probabilities","literature"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4617,), (4617, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Neural</span> <span style=''>Program</span> <span style='background-color:rgba(0, 255, 0, 0.6595744680851063);'>Synthesis</span> <span style=''>with</span> <span style=''>Priority</span> <span style=''>Queue</span> <span style=''>Training</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>program</span> <span style='background-color:rgba(0, 255, 0, 0.6595744680851063);'>synthesis</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>over</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>programs</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>programs</span> <span style=''>with</span> <span style=''>maximal</span> <span style=''>rewards</span> <span style=''>We</span> <span style=''>employ</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>where</span> <span style=''>we</span> <span style=''>train</span> <span style=''>an</span> <span style=''>RNN</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>K</span> <span style=''>best</span> <span style=''>programs</span> <span style=''>from</span> <span style=''>a</span> <span style=''>priority</span> <span style=''>queue</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>programs</span> <span style=''>so</span> <span style=''>far</span> <span style=''>Then</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>synthesize</span> <span style=''>new</span> <span style=''>programs</span> <span style=''>and</span> <span style=''>add</span> <span style=''>them</span> <span style=''>to</span> <span style=''>the</span> <span style=''>priority</span> <span style=''>queue</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>the</span> <span style=''>RNN</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.30169491525423725);'>benchmark</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>priority</span> <span style=''>queue</span> <span style=''>training</span> <span style=''>(or</span> <span style=''>PQT)</span> <span style=''>against</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.35365853658536595);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>baselines</span> <span style=''>on</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>Turing</span> <span style=''>complete</span> <span style='background-color:rgba(0, 255, 0, 0.3922651933701658);'>programming</span> <span style=''>language</span> <span style=''>called</span> <span style=''>BF</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.41328413284132853);'>experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>simple</span> <span style=''>PQT</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorith ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Managing</span> <span style=''>sparsity</span> <span style=''>time</span> <span style=''>and</span> <span style=''>quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>topic</span> <span style=''>models</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>is</span> <span style=''>an</span> <span style=''>integral</span> <span style=''>part</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>but</span> <span style=''>is</span> <span style=''>often</span> <span style=''>non</span> <span style=''>trivial</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>model</span> <span style=''>It</span> <span style=''>is</span> <span style=''>even</span> <span style=''>much</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>when</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>always</span> <span style=''>yields</span> <span style=''>sparse</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>denoted</span> <span style=''>by</span> <span style=''>FW</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>general</span> <span style=''>and</span> <span style=''>flexible</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>It</span> <span style=''>has</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>offers</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>us</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>way</span> <span style=''>to</span> <span style=''>directly</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>sparsity</span> <span style=''>against</span> <span style=''>quality</span> <span style=''>and</span> <span style=''>time</span> <span style=''>We</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3901808785529717);'>Stochastic</span> <span style=''>Proximal</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>for</span> <span style=''>Nuclear</span> <span style=''>Norm</span> <span style='background-color:rgba(255, 0, 0, 0.4);'>Regularization</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>utilize</span> <span style='background-color:rgba(255, 0, 0, 0.3901808785529717);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>composite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>a</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>where</span> <span style=''>the</span> <span style=''>variable</span> <span style=''>is</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>size</span> <span style=''>m</span> <span style=''>times</span> <span style=''>n</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3901808785529717);'>stochastic</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SPGD)</span> <span style=''>and</span> <span style=''>take</span> <span style=''>the</span> <span style=''>last</span> <span style=''>iterate</span> <span style=''>of</span> <span style=''>SPGD</span> <span style=''>as</span> <span style=''>the</span> <span style=''>final</span> <span style=''>solution</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>that</span> <span style=''>its</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style=''>O(mn)</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>most</span> <span style=''>of</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>a</span> <span style=''>O(mn)</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Theoretical</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>it</span> <span style=''>achieves</span> <span style=''>O(log</span> <span style=''>TsqrtT)</span> <span style=''>and</span> <span style=''>O(log</span> <span style=''>TT)</span> <span style='background-color:rgba(255, 0, 0, 0.35714285714285715);'>convergence</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>general</span> <span style=''>convex</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>DeepArchitect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Designing</span> <span style=''>and</span> <span style=''>Training</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Architectures</span> <br/><br/><span style=''>In</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>is</span> <span style=''>strongly</span> <span style=''>affected</span> <span style=''>by</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>While</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>for</span> <span style=''>simple</span> <span style=''>spaces</span> <span style=''>complex</span> <span style=''>spaces</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>remain</span> <span style=''>largely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexplored</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>is</span> <span style=''>done</span> <span style=''>manually</span> <span style=''>by</span> <span style=''>the</span> <span style=''>human</span> <span style=''>expert</span> <span style=''>through</span> <span style=''>a</span> <span style=''>slow</span> <span style=''>trial</span> <span style=''>and</span> <span style=''>error</span> <span style=''>process</span> <span style=''>guided</span> <span style=''>mainly</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuition</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>and</span> <span style=''>training</span> <span style=''>deep</span> <span style=''>models</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensible</span> <span style=''>and</span> <span style=''>modular</span> <span style=''>language</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>the</span> <span style=''>human</span> <span style=''>expert</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compactly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>complex</span> <span style=''>search</span> <span style=''>spaces</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>The</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08811987156617909)
# 	representation (0.1305743845879415)
# 	processing (0.10453085979307884)
# 	experimental (0.13663931501962184)
# 	segmentation (0.07634677131644667)
# 	knowledge (0.14306100606493044)
# 	different (0.2600784873349982)
# 	detection (0.12593649661077416)
# 	recognition (0.12879058151980022)
# 	convolutional (0.14270424545130217)
#
# Some Statistics words are:
# 	theoretical (0.1457185778668002)
# 	stochastic (0.13470205307961944)
# 	algorithm (0.3800701051577366)
# 	statistical (0.15823735603405106)
# 	variables (0.14221331997996994)
# 	estimation (0.1772658988482724)
# 	distribution (0.1927891837756635)
# 	inference (0.19679519278918378)
# 	dimensional (0.18627941912869303)
# 	regression (0.18027040560841262)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ee9bc280-a227-455c-98a0-8f9b2828d53a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee9bc280-a227-455c-98a0-8f9b2828d53a")) {                    Plotly.newPlot(                        "ee9bc280-a227-455c-98a0-8f9b2828d53a",                        [{"x":["empirically","application","computational","components","semantics","architecture","probabilities","literature","performance","prediction","competitive","plausible","structured","retrieval","relational","processing","information","generated","continuous","optimization","conducted","propagation","represent","optimizing","significantly","different","operation","characterize","equivalent","invariant","complexity","redundant","particular","efficient","including","algorithms","experimental","gradients","rescaling","functions","properties","demonstrate","convolutional","stochastic","effectiveness","activation","connected","dimension","conventional","simulations","computationally","magnitude","inversion","stabilize","estimates","regularization","motivated","resulting","stabilizing","complicated","tomography","direction","alternating","exploiting","multipliers","measurements","attractive","performed","techniques","physically","sensitive","artifacts","coefficients","characterization","distribution","decomposing","materials","commercial","absorption","reconstructions","iterative","classification","substantially","consistency","condition","conditional","typically","orthogonal","influence","applications","partially","penalties","variables","brightness","distinguish","specifically","identifier","sometimes","robustness","following","adversarial","minimizing","generally","regression","interventions","exhibiting","improving","unsupervised","reconstruction","penalizes","experiments","knowledge","symmetric","invariance","autoencoders","exhibited","transformations","extending","bootstrapping","effectively","principally","recursive","framework","assumption","practical","convexity","convergence","efficiency","algorithm","numerical","comparing","minimization","respective","sufficient","reasonable","precisely","stakeholders","discomfort","foundation","questions","desiderata","consideration","significant","injecting","interpretable","synthesis","supervisory","evaluation","objective","estimation","sequences","supervised","simultaneously","performing","comparably","independently","empirical","comparable","unstructured","established","demonstrates","monocular","favorably","explosive","automated","microwave","restricted","detecting","something","environmental","statistical","processed","controlling","validated","implemented","detection","implement","statistically","environment","approximated","benchmark","reconstruct","curvature","refinement","interpolate","variational","superiority","interpolation","estimated","resolution","subjective","testified","curvatures","optimized","technique","measurement","dimensions","generalize","approaches","metrology","nonparametric","clustering","documents","expectation","extensible","considered","streaming","applicable","straightforwardly","inference","unfortunately","scenarios","filtering","processes","normalized","dirichlet","minimized","guarantees","sufficiently","polynomial","developed","constants","logarithm","efficiently","especially","additionally","locations","recognize","introduce","capability","distributed","interaction","instantaneous","understood","decomposed","intelligent","intuitively","violation","artificial","interactions","notoriously","component","independence","machinery","cognitive","computation","networked","biological","independent","environments","difficult","instantaneously","regardless","evolution","intuition","probabilistic","dependent","themselves","tr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	emphstatistical
# 	semiparametric
# 	idealized
# 	maximizer
# 	assertion
# 	varepsilon
# 	stagewise
# 	photovoltaic
# 	substantive
# 	tempering
# 	dissertation
# 	astronomy
# 	extrapolating
# 	transposable
# 	correntropy
# 	unavoidably
# 	nutrition
# 	deflation
# 	stepsizes
# 	minimises
# Some words which never appear in Statistics papers:
# 	absorption
# 	monocular
# 	explosive
# 	something
# 	instantaneously
# 	descriptive
# 	postulates
# 	illuminating
# 	predicates
# 	suppliers
# 	optimised
# 	statically
# 	configured
# 	dialectal
# 	orthography
# 	cooperate
# 	biometric
# 	attentive
# 	facilities
# 	affective

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0630685821055535e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7483333333333333
